# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import tickbars

# %%
raw_data = pd.read_csv('ESU13_tickdata.csv')
data_indexed = raw_data.copy()
data_indexed['time'] = pd.to_datetime(data_indexed['time'], format='%m/%d/%Y %H:%M:%S.%f')

# %%
imbalance = tickbars.tick_rule(data_indexed['price'])
p_b_up = (imbalance.mean().item()+1)/2
print(p_b_up)
# Out:
# 0.5038884176348081

# %%
volume = data_indexed['volume']
volume_imbalance = imbalance*volume
volume_up = np.mean([v for v in volume_imbalance if v > 0])
volume_down = -np.mean([v for v in volume_imbalance if v < 0])
print(volume_up, volume_down)
# Out:
# 4.019840722741713 3.99696861519082

# %%
ties = tickbars.DollarVolumeRunsEvents(imbalance, volume, 100000, imbalance.mean().item(), volume_up, volume_down, 2*1e-5)

# %%
tick_imb_tevents = ties.get_events()

# %%
tick_imb_tevents['time'] = data_indexed.loc[tick_imb_tevents.index, 'time']
tick_imb_tevents['time'] = pd.to_datetime(tick_imb_tevents['time'], format='%m/%d/%Y %H:%M:%S.%f')
tick_imb_tevents
# Out:
#              threshold                    time
# tevent
# 127307   202555.118093 2013-09-03 07:13:20.013
# 210338   169279.037844 2013-09-03 09:04:40.574
# 303669   182807.316772 2013-09-03 10:23:55.940
# 399103   207498.292317 2013-09-03 11:49:54.314
# 508577   209853.581533 2013-09-03 14:00:02.230
# 588977   196857.519906 2013-09-03 15:05:09.034
# 714586   221828.013421 2013-09-04 08:58:41.814
# 798035   191994.471826 2013-09-04 10:28:15.123
# 887408   209601.802029 2013-09-04 13:03:39.311
# 985920   230494.768907 2013-09-04 15:33:23.510
# 1126151  246181.092369 2013-09-05 09:23:37.508
# 1220697  189342.615789 2013-09-05 11:38:49.150
# 1306629  193347.605871 2013-09-05 15:31:00.391
# 1434160  224009.161199 2013-09-06 08:35:37.100
# 1520507  190352.540070 2013-09-06 08:51:44.374
# 1623254  192062.519670 2013-09-06 09:21:01.909
# 1713954  195424.707466 2013-09-06 10:10:07.619
# 1809149  214018.451510 2013-09-06 12:46:53.233
# 1914331  215802.287284 2013-09-06 14:49:40.438
# 2019304  215474.856612 2013-09-09 08:40:59.570
# 2117978  192400.327340 2013-09-09 10:26:00.304
# 2204078  199369.712559 2013-09-09 13:08:12.079
# 2289182  220009.782636 2013-09-09 15:14:35.853
# 2420315  254154.900119 2013-09-10 08:55:55.025
# 2518913  202305.768345 2013-09-10 10:30:00.091
# 2609033  202610.132139 2013-09-10 12:46:46.655
# 2702256  217892.423175 2013-09-10 15:01:20.391
# 2834247  239530.316819 2013-09-11 09:08:53.485
# 2920629  195381.268643 2013-09-11 10:34:49.275
# 3004908  217772.460637 2013-09-11 13:08:45.312
# 3104352  239446.317772 2013-09-12 05:10:22.761
# 3245447  242722.775861 2013-09-12 11:03:00.356
# 3340606  189843.394269 2013-09-12 14:58:36.091
# 3354192  192984.906452 2013-09-12 16:14:58.709

# %%
statistics = pd.DataFrame({'value': ties.statistics, 'time': data_indexed.loc[ties.statistics.index, 'time']})

# %%
plt.figure(figsize=(15, 5))
plt.plot(statistics['time'], statistics['value'])
plt.step(tick_imb_tevents['time'], tick_imb_tevents['threshold'], where='pre')
plt.show()

# %%
data_indexed['grp'] = 0
data_indexed.loc[tick_imb_tevents.index[:-1], 'grp'] = 1
data_indexed['grp'] = np.cumsum(data_indexed['grp'])
data_tick_vwap = tickbars.create_bars(data_indexed, 'grp', tickbars.compute_bar)

# %%
data_tick_vwap
# Out:
#                       time     open     high      low    close  volume  \
# 0  2013-09-03 07:13:20.013  1640.25  1649.00  1639.00  1643.75  399334
# 1  2013-09-03 09:04:40.574  1643.75  1650.00  1643.75  1646.50  325969
# 2  2013-09-03 10:23:55.940  1646.50  1648.75  1640.25  1640.75  350472
# 3  2013-09-03 11:49:54.314  1640.75  1641.50  1633.75  1634.75  395900
# 4  2013-09-03 14:00:02.230  1634.75  1635.50  1630.75  1635.00  405977
# 5  2013-09-03 15:05:09.034  1635.00  1639.50  1634.25  1637.75  368354
# 6  2013-09-04 08:58:41.814  1637.75  1643.75  1635.00  1642.50  436183
# 7  2013-09-04 10:28:15.123  1642.50  1649.75  1642.25  1649.00  364421
# 8  2013-09-04 13:03:39.311  1649.00  1654.75  1648.50  1652.25  412866
# 9  2013-09-04 15:33:20.295  1652.25  1654.25  1649.50  1654.00  430290
# 10 2013-09-05 09:23:37.508  1654.00  1658.25  1650.50  1656.00  486257
# 11 2013-09-05 11:38:49.150  1656.00  1657.25  1652.50  1654.25  376147
# 12 2013-09-05 15:31:00.391  1654.25  1656.75  1652.50  1653.25  377589
# 13 2013-09-06 08:35:37.100  1653.25  1663.50  1648.50  1660.00  418121
# 14 2013-09-06 08:51:44.374  1660.00  1661.00  1642.25  1647.25  354318
# 15 2013-09-06 09:21:01.909  1647.25  1648.75  1638.75  1647.00  379391
# 16 2013-09-06 10:10:07.619  1647.00  1660.25  1646.25  1658.50  366318
# 17 2013-09-06 12:46:53.233  1658.50  1660.75  1656.00  1659.75  423453
# 18 2013-09-06 14:49:40.438  1659.75  1664.00  1654.75  1655.00  404231
# 19 2013-09-09 08:40:59.570  1655.00  1662.25  1652.00  1661.50  420777
